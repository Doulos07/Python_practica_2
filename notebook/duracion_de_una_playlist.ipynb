# %%
import sys
sys.path.append("../src")

# Importo los codigos que voy a utilizar
from datos import playlist
import ejercicio2

# %%
print(ejercicio2.duracion_playlist())
print(ejercicio2.filter_playlist())
print(ejercicio2.filter_playlist(filter='min'))
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" "8:02"
# Canción más corta: "Imagine" "3:07"
