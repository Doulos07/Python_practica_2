# %%
import sys
sys.path.append("../src")

# Importo los datos que voy a utilizar como parametro
import datos
# Importo el codigo de cada ejercicio:
import ejercicio1, ejercicio2, ejercicio3, ejercicio4, ejercicio5, ejercicio6, ejercicio7, ejercicio8, ejercicio9, ejercicio10

# %%
# A partir de este texto:
text = datos.text
print(text)
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way
# to do it.
# Although that way may not be obvious at first unless you're
# Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good
# idea.
# Namespaces are one honking great idea -- let's do more of
# those!

# %%
# Ejercicio 1
print(ejercicio1.cantidad_lineas(text))
print(ejercicio1.cantidad_palabras(text))
print(ejercicio1.promedio_palabras(text))
promedio = ejercicio1.encima_promedio(text)
for prom in promedio:
    print(prom)
# Out:
# 19
# 137
# 7.21
#
# Special cases aren't special enough to break the rules
#
# In the face of ambiguity, refuse the temptation to guess
#
# There should be one-- and preferably only one --obvious way
# to do it
#
# Although that way may not be obvious at first unless you're
# Dutch
#
# Although never is often better than *right* now
#
# If the implementation is hard to explain, it's a bad idea
#
# If the implementation is easy to explain, it may be a good
# idea
#
# Namespaces are one honking great idea -- let's do more of
# those!

# %%
playlist = datos.playlist
for song in playlist:
    for k, v in song.items():
        print(f'{k} : {v}')
    print()
# Out:
# title : Bohemian Rhapsody
# duration : 5:55
#
# title : Hotel California
# duration : 6:30
#
# title : Stairway to Heaven
# duration : 8:02
#
# title : Imagine
# duration : 3:07
#
# title : Smells Like Teen Spirit
# duration : 5:01
#
# title : Billie Jean
# duration : 4:54
#
# title : Hey Jude
# duration : 7:11
#
# title : Like a Rolling Stone
# duration : 6:13

# %%
# Ejercicio 2
print(ejercicio2.duracion_playlist(playlist))
print(ejercicio2.filter_playlist(playlist))
print(ejercicio2.filter_playlist(playlist, filter='min'))
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" "8:02"
# Canción más corta: "Imagine" "3:07"

# %%
# ejercicio 3
review = datos.review
spoiler = input('Ingrese las palabras spoiler (separadas por coma):').split(',')
ejercicio3.filter_spoiler(review, spoiler)
# Out:
# Ingrese las palabras spoiler (separadas por coma): Torres, NAVE, TARJETA, Marte
# 'La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate. El capitán ****** lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a ***** descubren que la base está abandonada y los suministros destruidos. ****** decide sacrificar la **** nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que ****** sobrevivió gracias a un pasaje secreto.'

# %%
# Ejercicio 4
mail = input('ingrese su mail').strip()
ejercicio4.validation_mail(mail)
# Out:
# ingrese su mail Santiago@gmail.com
# 'Mail valido'

# %%
# Ejercicio 5
peso = float(input('Ingrese el peso del paquete (KG): '))
zona = input('Ingrese la zona de destino (local/regional/nacional): ').strip().lower()
ejercicio5.calcular_envio(peso, zona)
# Out:
# Ingrese el peso del paquete (KG):  2
# Ingrese la zona de destino (local/regional/nacional):  local
# 'Costo del envío: $1000'

# %%
# Ejercicio 6
posts = datos.posts
tendencia, total = ejercicio6.analisar_hastags(posts)
print('Hashtags trending (más de una aparición):')
for k, v in tendencia.items():
    print(f'{k}: {v}')
print(f'Total de hashtags únicos: {total}')
# Out:
# Hashtags trending (más de una aparición):
# #Motivación: 2
# #Python: 3
# #Programación: 3
# #SerieAdicta: 2
# #InteligenciaArtificial: 3
# #Tecnología: 2
# Total de hashtags únicos: 13

# %%
# Ejercicio 7
personas = input('ingreso los amigos secretos: ').split(',')
parejas = ejercicio7.sorteo_amigo_invisible(personas)
if len(parejas) != 0:
    for pj in parejas:
        print(f'{pj[0]} -> {pj[1]}')
else:
    print('tiene que ser 3 o mas personas')
# Out:
# ingreso los amigos secretos:  santiago, ariel, alvarez, alvarez
# ariel -> alvarez
# santiago -> ariel
# alvarez -> santiago

# %%
# Ejercicio 8
mensaje = input('Ingrese un mensaje: ')
desplazamiento = int(input('Ingrese el desplazamiento: '))
ejercicio8.cifrar_mensaje(mensaje, desplazamiento)

# %%
# Ejercicio 9
students = datos.students
datos = ejercicio9.normalizar_registro(students)
for dato in datos:
    for k, v in dato.items():
        print(f'{k} : {v}')
    print()
print(f'total de alumnos validos: {len(datos)}')
# Out:
# name : Ana garcía
# grade : 9
# status : Aprobado
#
# name : Carlos ruiz
# grade : 6
# status : Aprobado
#
# name : Gabriela ríos
# grade : 5
# status : Aprobado
#
# name : Laura méndez
# grade : 8
# status : Aprobado
#
# name : María fernández
# grade : 10
# status : Aprobado
#
# name : Pedro lópez
# grade : 4
# status : Desaprobado
#
# name : Sofía torres
# grade : 9
# status : Aprobado
#
# total de alumnos validos: 7

# %%
rounds = datos.rounds
ejercicio10.competence(rounds)
# Out:
# Ronda 1 - Entrada:
# Ganador: Camila (26 pts)
# Cocinero          Puntaje           Rondas Ganadas    Mejor Ronda
# ------------------------------------------------------------------------
# Camila            26                1                 26
# Valentina         24                0                 24
# Lucía             24                0                 24
# Mateo             22                0                 22
# Santiago          19                0                 19
# ------------------------------------------------------------------------
# Ronda 2 - Plato principal:
# Ganador: Valentina (26 pts)
# Cocinero          Puntaje           Rondas Ganadas    Mejor Ronda
# ------------------------------------------------------------------------
# Valentina         50                1                 26
# Camila            46                1                 26
# Lucía             46                0                 24
# Mateo             46                0                 24
# ...
